# %% [markdown]
# # Sporting Plaid - Part 2

# %% [markdown]
# It's time to join the reovlution and to fight for the democratization of financial services. Now that your Plaid API keys are stored as Python variables, submit requests to the Plaid API using the Plaid SDK. Extract credit card interest payments for all accounts.

# %%
import plaid
import os
import datetime
import json

# %% [markdown]
# ### Pull in env variable as Python variables

# %%
# Bring env variables into Python and store in variables
PLAID_CLIENT_ID = os.getenv("PLAID_CLIENT_ID")
PLAID_PUBLIC_KEY = os.getenv("PLAID_PUBLIC_KEY")
PLAID_SBX_SECRET_KEY = os.getenv("PLAID_SBX_SECRET_KEY")

# %% [markdown]
# ### Extract list of institutions from Plaid

# %%
# Create client object
client = plaid.Client(client_id=PLAID_CLIENT_ID, public_key=PLAID_PUBLIC_KEY, secret=PLAID_SBX_SECRET_KEY, environment="sandbox")

# %% [markdown]
# ### Create public token and exchange for access token

# %%
# Select an institution for processing
INSTITUTION_ID = "ins_109512"

# Create public token to be exchanged for institution access token
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions', 'income', 'assets'])

# Exchange public token for access token
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])

# Store access token as variable
access_token = exchange_response['access_token']

# %% [markdown]
# ### Extract transactions from Plaid

# %%
# Extract Transactions with date range
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-365))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now()) 

# Execute get request for transactions
big_list = client.Transactions.get(access_token, start_date, end_date)
big_list
# Out:
# {'accounts': [{'account_id': 'ZXDvXm8A6RsEXQ3wXoRqSGejVdKx3zFga38Ep',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': 'MvGpvKjV6XTkZrPnZabRSGXW9yqJLpF9XKDWr',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': '1d3bd94B58IlvoBwva4ACZVo5Apm8WC59zQka',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '2222',
#    'name': 'Plaid CD',
#    'official_name': 'Plaid Bronze Standard 0.2% Interest CD',
#    'subtype': 'cd',
#    'type': 'depository'},
#   {'account_id': 'LvyLvq4w6XTZwKPEwd8ouj6obaNAXKtP67Lx4',
#    'balances': {'available': None,
#     'current': 410,
#     'iso_currency_code': 'USD',
#     'limit': 2000,
#     'unofficial_currency_code': None},
#    'mask': '3333',
#    'name': 'Plaid Credit Card',
#    'official_name': 'Plaid Diamond 12.5% APR Interest Credit Card',
#    'subtype': 'credit card',
#    'type': 'credit'},
#   {'account_id': 'pNp1NWPmZ4Hb4kQr4PZaTaJwbyKrjVfLlwDv9',
#    'balances': {'available': 43200,
#     'current': 43200,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '4444',
#    'name': 'Plaid Money Market',
#    'official_name': 'Plaid Platinum Standard 1.85% Interest Money Market',
#    'subtype': 'money market',
#    'type': 'depository'},
#   {'account_id': 'o4NM4wJoQaHL4kVK4RnWuxzQLjBMK6cRQjXZX',
#    'balances': {'available': None,
#     'current': 320.76,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '5555',
#    'name': 'Plaid IRA',
#    'official_name': None,
#    'subtype': 'ira',
#    'type': 'investment'},
#   {'account_id': 'gKZ4KmP6dqIGdNpKdRQJS75XyGZ9wnhgNol6g',
#    'balances': {'available': None,
#     'current': 23631.9805,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '6666',
#    'name': 'Plaid 401k',
#    'official_name': None,
#    'subtype': '401k',
#    'type': 'investment'},
#   {'account_id': '8eVle9DPAXfZMrmAMWbzuVzojbKkaniw7nxXW',
#    'balances': {'available': None,
#     'current': 65262,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '7777',
#    'name': 'Plaid Student Loan',
#    'official_name': None,
#    'subtype': 'student',
#    'type': 'loan'}],
#  'item': {'available_products': ['balance',
#    'credit_details',
#    'identity',
#    'investments',
#    'liabilities'],
#   'billed_products': ['assets', 'income', 'transactions'],
#   'consent_expiration_time': None,
#   'error': None,
#   'institution_id': 'ins_109512',
#   'item_id': 'wM9WM8b1wZHxbyWAbljeUrPN3JVno6urbKdM6',
#   'webhook': ''},
#  'request_id': 'RIpprB2TVxbYoRH',
#  'total_transactions': 16,
#  'transactions': [{'account_id': 'LvyLvq4w6XTZwKPEwd8ouj6obaNAXKtP67Lx4',
#    'account_owner': None,
#    'amount': 500,
#    'authorized_date': None,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2020-03-31',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_channel': 'in store',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'dvaxvmD9BbTEblDjbygRSJR3kaaaP6FZykPMb',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'ZXDvXm8A6RsEXQ3wXoRqSGejVdKx3zFga38Ep',
#    'account_owner': None,
#    'amount': 6.33,
#    'authorized_date': None,
#    'category': ['Travel', 'Taxi'],
#    'category_id': '22016000',
#    'date': '2020-03-29',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber',
#    'payment_channel': 'in store',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'k3j738xoPBFGLMrgLX3ySomZabbb47FW79xQ7',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'LvyLvq4w6XTZwKPEwd8ouj6obaNAXKtP67Lx4',
#    'account_owner': None,
#    'amount': 500,
#    'authorized_date': None,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2020-03-26',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Tectra Inc',
#    'payment_channel': 'in store',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'avyzvmBGKDTlodymonw7Cwq93bbbWvU76NRaa',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'LvyLvq4w6XTZwKPEwd8ouj6obaNAXKtP67Lx4',
#    'account_owner': None,
#    'amount': 2078.5,
#    'authorized_date': None,
#    'category': ['Payment'],
#    'category_id': '16000000',
#    'date': '2020-03-25',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'AUTOMATIC PAYMENT - THANK',
#    'payment_channel': 'other',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'PvX8vBQA6VTeX3NvXPx7TQD3xVVVPWt7L1wkR',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'LvyLvq4w6XTZwKPEwd8ouj6obaNAXKtP67Lx4',
#    'account_owner': None,
#    'amount': 500,
#    'authorized_date': None,
#    'category': ['Food and Drink', 'Restaurants', 'Fast Food'],
#    'category_id': '13005032',
#    'date': '2020-03-25',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'KFC',
#    'payment_channel': 'in store',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'Nvbovr7y6XTnVzNZV4kqSRJlG6664LtW83rjd',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'LvyLvq4w6XTZwKPEwd8ouj6obaNAXKtP67Lx4',
#    'account_owner': None,
#    'amount': 500,
#    'authorized_date': None,
#    'category': ['Shops', 'Sporting Goods'],
#    'category_id': '19046000',
#    'date': '2020-03-25',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Madison Bicycle Shop',
#    'payment_channel': 'in store',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': '4Nj9NJadDmHG7oMj7LblSLlP4nnnz8idpogr5',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'MvGpvKjV6XTkZrPnZabRSGXW9yqJLpF9XKDWr',
#    'account_owner': None,
#    'amount': 25,
#    'authorized_date': None,
#    'category': ['Payment', 'Credit Card'],
#    'category_id': '16001000',
#    'date': '2020-03-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CREDIT CARD 3333 PAYMENT *//',
#    'payment_channel': 'other',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'BEd4E3DWAXFA1jlB1GV7IZdpjwwwM4fwvB7WK',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'ZXDvXm8A6RsEXQ3wXoRqSGejVdKx3zFga38Ep',
#    'account_owner': None,
#    'amount': 5.4,
#    'authorized_date': None,
#    'category': ['Travel', 'Taxi'],
#    'category_id': '22016000',
#    'date': '2020-03-16',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Uber',
#    'payment_channel': 'in store',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'lx5exy9oj3IxRDzBRW3XUKqodrrr1BtZB4Lwg',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'pNp1NWPmZ4Hb4kQr4PZaTaJwbyKrjVfLlwDv9',
#    'account_owner': None,
#    'amount': 5850,
#    'authorized_date': None,
#    'category': ['Transfer', 'Debit'],
#    'category_id': '21006000',
#    'date': '2020-03-15',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'ACH Electronic CreditGUSTO PAY 123456',
#    'payment_channel': 'other',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': 'ACH',
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': '773679aNmkS5RAGmRxMrsKZQGvvvxetgbZNlz',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': '1d3bd94B58IlvoBwva4ACZVo5Apm8WC59zQka',
#    'account_owner': None,
#    'amount': 1000,
#    'authorized_date': None,
#    'category': ['Transfer', 'Deposit'],
#    'category_id': '21007000',
#    'date': '2020-03-15',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'CD DEPOSIT .INITIAL.',
#    'payment_channel': 'other',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'x1wA1QgmyMfx5z3w56dEUrd15QQQDEFnM1971',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'LvyLvq4w6XTZwKPEwd8ouj6obaNAXKtP67Lx4',
#    'account_owner': None,
#    'amount': 78.5,
#    'authorized_date': None,
#    'category': ['Recreation', 'Gyms and Fitness Centers'],
#    'category_id': '17018000',
#    'date': '2020-03-14',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Touchstone Climbing',
#    'payment_channel': 'in store',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'jBXjB8J6NzIdN7VBNgzXcR4Kk333Wzt1KEyMj',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'ZXDvXm8A6RsEXQ3wXoRqSGejVdKx3zFga38Ep',
#    'account_owner': None,
#    'amount': -500,
#    'authorized_date': None,
#    'category': ['Travel', 'Airlines and Aviation Services'],
#    'category_id': '22001000',
#    'date': '2020-03-14',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'United Airlines',
#    'payment_channel': 'other',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'qPpLP8boMkIXjoQZj9M1CwbkMqqqBjUdlEJmr',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None},
#   {'account_id': 'ZXDvXm8A6RsEXQ3wXoRqSGejVdKx3zFga38Ep',
#    'account_owner': None,
#    'amount': 12,
#    'authorized_date': None,
#    'category': ['Food and Drink', 'Restaurants', 'Fast Food'],
#    'category_id': '13005032',
#    'date': '2020-03-13',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': '3322'},
#    'name': "McDonald's",
#    'payment_channel': 'in store',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'Kv91vl4W6XTv7qPE7xR4uwo9zWWWxGUVoy6ZX',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'ZXDvXm8A6RsEXQ3wXoRqSGejVdKx3zFga38Ep',
#    'account_owner': None,
#    'amount': 4.33,
#    'authorized_date': None,
#    'category': ['Food and Drink', 'Restaurants', 'Coffee Shop'],
#    'category_id': '13005043',
#    'date': '2020-03-13',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'Starbucks',
#    'payment_channel': 'in store',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'rkypkmgo1PhyXZleXKBwSNxvMqqqglFlbQyPe',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'ZXDvXm8A6RsEXQ3wXoRqSGejVdKx3zFga38Ep',
#    'account_owner': None,
#    'amount': 89.4,
#    'authorized_date': None,
#    'category': ['Food and Drink', 'Restaurants'],
#    'category_id': '13005000',
#    'date': '2020-03-12',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'SparkFun',
#    'payment_channel': 'in store',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': 'zpxkpDa1VLHzgyRqgE9Ks3q1mooon8TodVE7G',
#    'transaction_type': 'place',
#    'unofficial_currency_code': None},
#   {'account_id': 'MvGpvKjV6XTkZrPnZabRSGXW9yqJLpF9XKDWr',
#    'account_owner': None,
#    'amount': -4.22,
#    'authorized_date': None,
#    'category': ['Transfer', 'Credit'],
#    'category_id': '21005000',
#    'date': '2020-03-11',
#    'iso_currency_code': 'USD',
#    'location': {'address': None,
#     'city': None,
#     'country': None,
#     'lat': None,
#     'lon': None,
#     'postal_code': None,
#     'region': None,
#     'store_number': None},
#    'name': 'INTRST PYMNT',
#    'payment_channel': 'other',
#    'payment_meta': {'by_order_of': None,
#     'payee': None,
#     'payer': None,
#     'payment_method': None,
#     'payment_processor': None,
#     'ppd_id': None,
#     'reason': None,
#     'reference_number': None},
#    'pending': False,
#    'pending_transaction_id': None,
#    'transaction_code': None,
#    'transaction_id': '34wy49Gxo5HGn1yBno7QSNj8adddEoFqgAwrp',
#    'transaction_type': 'special',
#    'unofficial_currency_code': None}]}

# %% [markdown]
# ### Parse JSON output

# %%
# Iterate and parse JSON response
for transactions in big_list["transactions"]:
    if transactions['name'] == "INTRST PYMNT":
        print(transactions['amount'])
# Out:
# -4.22

# %%
cnt = 0
for transactions in big_list["transactions"]:
    print(transactions['amount'], json.dumps(transactions["category"], indent = 4, sort_keys = True))
    cnt += 1
    if cnt > 5:
        break
# Out:
# 500 [
#     "Travel",
#     "Airlines and Aviation Services"
# ]
# 6.33 [
#     "Travel",
#     "Taxi"
# ]
# 500 [
#     "Food and Drink",
#     "Restaurants"
# ]
# 2078.5 [
#     "Payment"
# ]
# 500 [
#     "Food and Drink",
#     "Restaurants",
#     "Fast Food"
# ]
# 500 [
#     "Shops",
#     "Sporting Goods"
# ]

# %%
# Mess with Assets, different than transactions because you have to make a report

response = client.AssetReport.create([access_token], days_requested=10)
print(response)
# Out:
# {'asset_report_id': '526afc5e-a801-4700-bbf9-55c5c6f1dbea', 'asset_report_token': 'assets-sandbox-e981b5d6-f2bc-4577-af80-c9de4979dd50', 'request_id': 'Q2YFa36A4HRJWiF'}

# %%
asset_report_token = response['asset_report_token']

reportResponse = client.AssetReport.get(asset_report_token)
report = reportResponse['report']
# print(json.dumps(report,indent=4))

# print(json.dumps(report['items'][0]["accounts"], indent=4))

myDict = {}
for account in report['items'][0]["accounts"]:
# print(account["name"],json.dumps(account["balances"], indent = 4))
# print(account["name"],(account["balances"]["current"]))
    myDict[account["name"]] = float(account["balances"]["current"])
    #print(myDict)
    
sum = 0
for key, value in myDict.items():
    if "Credit Card" in key or "Loan" in key:
        value = -1 * value
    sum = sum + value
print(f"Net Worth: {sum}")
# Out:
# Net Worth: 2800.740500000007
