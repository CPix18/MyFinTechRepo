# %% [markdown]
# # Students Do: Preventing credit card defaults with neural networks
#
# In this activity, you will train a neural network model to predict whether a credit card holder will default in the next month.
#
# The dataset provided contains `30,000` anonymous records of credit default status with `23` features columns and one binary target column entitled _DEFAULT_, where `1` represents a defaulted credit card.
#
# The `23` features include demographic info (age, gender, marital status, etc.), credit limit, past payment details, and other relevant information.
#
# You are tasked to create a neural network model to predict if a credit card holder will default.

# %%
# Initial imports
from pathlib import Path
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# ## Instructions
#
# 1. Load the data in a Pandas DataFrame.

# %%
# Read in data
file_path = Path("../Resources/cc_default.csv")
df = pd.read_csv(file_path)
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...           "BILL_AMT4"  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -2  ...                     0          0          0         0       689
# 1      0  ...                  3272       3455       3261         0      1000
# 2      0  ...                 14331      14948      15549      1518      1500
# 3      0  ...                 28314      28959      29547      2000      2019
# 4      0  ...                 20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0         0         0         0         0        1
# 1      1000      1000         0      2000        1
# 2      1000      1000      1000      5000        0
# 3      1200      1100      1069      1000        0
# 4     10000      9000       689       679        0
#
# [5 rows x 24 columns]

# %% [markdown]
# 2. Define the features set `X` by including all the columns of the DataFrame except the `DEFAULT` column.

# %%
# Define features data
X = df.copy()
X = df.drop(columns = ["DEFAULT"])
X.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT3           "BILL_AMT4"  BILL_AMT5  BILL_AMT6  \
# 0     -2  ...        689                     0          0          0
# 1      0  ...       2682                  3272       3455       3261
# 2      0  ...      13559                 14331      14948      15549
# 3      0  ...      49291                 28314      28959      29547
# 4      0  ...      35835                 20940      19146      19131
#
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0         0       689         0         0         0         0
# 1         0      1000      1000      1000         0      2000
# 2      1518      1500      1000      1000      1000      5000
# 3      2000      2019      1200      1100      1069      1000
# 4      2000     36681     10000      9000       689       679
#
# [5 rows x 23 columns]

# %% [markdown]
# 3. Create the target vector `y` by assigning the values of the `DEFAULT` column of the DataFrame.

# %%
# Define target data
y = df["DEFAULT"].values
y = y.reshape(-1, 1)
y[:5]
# Out:
# array([[1],
#        [1],
#        [0],
#        [0],
#        [0]])

# %% [markdown]
# 4. Create the training an testing sets using the `train_test_split` function from `sklearn`.

# %%
# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %% [markdown]
# 5. Scale the features data using the `StandardScaler` from `sklearn`.

# %%
# Create the scaler instance
X_scaler = StandardScaler()

# %%
# Fit the scaler
X_scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Scale the features data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# 6. Create a neural network model with `23` inputs, one hidden layer with `69` units, and an output layer with a single output. Use the `relu` activation function for the first layer and `sigmoid` for the second layer.

# %%
# Define the model
number_inputs = 23
number_hidden_nodes = 69
nn = Sequential()
nn.add(Dense(units=number_hidden_nodes, input_dim=number_inputs, activation="relu"))
nn.add(Dense(1, activation="sigmoid"))

# %% [markdown]
# 7. Compile the neural network model using the `binary_crossentropy` loss function, the `adam` optimizer, and `accuracy` as additional metric.

# %%
# Compile model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# 8. Fit the model with `100` epochs.

# %%
# Fit the model
model = nn.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4818 - accuracy: 0.8005
# Epoch 2/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4494 - accuracy: 0.8144
# Epoch 3/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4440 - accuracy: 0.8168
# Epoch 4/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4404 - accuracy: 0.8174
# Epoch 5/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4372 - accuracy: 0.8173
# Epoch 6/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4360 - accuracy: 0.8173: 0s - loss: 0.4378 - accura
# Epoch 7/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4345 - accuracy: 0.8182
# Epoch 8/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4327 - accuracy: 0.8191
# Epoch 9/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4319 - accuracy: 0.8193
# Epoch 10/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4308 - accuracy: 0.8214
# Epoch 11/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4298 - accuracy: 0.8194
# Epoch 12/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4295 - accuracy: 0.8208
# Epoch 13/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4282 - accuracy: 0.8193
# Epoch 14/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4279 - accuracy: 0.8215
# Epoch 15/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4272 - accuracy: 0.8214
# Epoch 16/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4268 - accuracy: 0.8209
# Epoch 17/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4261 - accuracy: 0.8198
# Epoch 18/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4253 - accuracy: 0.8210
# Epoch 19/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4248 - accuracy: 0.8211
# Epoch 20/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4241 - accuracy: 0.8208
# Epoch 21/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4244 - accuracy: 0.8207
# Epoch 22/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4231 - accuracy: 0.8210
# Epoch 23/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4232 - accuracy: 0.8209
# Epoch 24/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4231 - accuracy: 0.8232
# Epoch 25/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4227 - accuracy: 0.8227
# Epoch 26/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4218 - accuracy: 0.8220
# Epoch 27/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4213 - accuracy: 0.8215
# Epoch 28/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4210 - accuracy: 0.8228
# Epoch 29/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4212 - accuracy: 0.8216
# Epoch 30/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4209 - accuracy: 0.8234
# Epoch 31/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4201 - accuracy: 0.8218
# Epoch 32/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4199 - accuracy: 0.8215
# Epoch 33/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4199 - accuracy: 0.8219
# Epoch 34/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4192 - accuracy: 0.8216
# Epoch 35/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4190 - accuracy: 0.8212
# Epoch 36/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4184 - accuracy: 0.8211
# Epoch 37/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4182 - accuracy: 0.8232
# Epoch 38/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4182 - accuracy: 0.8240
# Epoch 39/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4176 - accuracy: 0.8226
# Epoch 40/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4183 - accuracy: 0.8223
# Epoch 41/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4167 - accuracy: 0.8235
# Epoch 42/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4170 - accuracy: 0.8233
# Epoch 43/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4168 - accuracy: 0.8234
# Epoch 44/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4160 - accuracy: 0.8219
# Epoch 45/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4163 - accuracy: 0.8228
# Epoch 46/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4156 - accuracy: 0.8230
# Epoch 47/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4155 - accuracy: 0.8227
# Epoch 48/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4154 - accuracy: 0.8239
# Epoch 49/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4152 - accuracy: 0.8231
# Epoch 50/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4150 - accuracy: 0.8232
# Epoch 51/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4142 - accuracy: 0.8238
# Epoch 52/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4147 - accuracy: 0.8237
# Epoch 53/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4138 - accuracy: 0.8244: 0s - los
# Epoch 54/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4146 - accuracy: 0.8234
# Epoch 55/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4136 - accuracy: 0.8254
# Epoch 56/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4132 - accuracy: 0.8251
# Epoch 57/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4136 - accuracy: 0.8235
# Epoch 58/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4128 - accuracy: 0.8240
# Epoch 59/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4134 - accuracy: 0.8246
# Epoch 60/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4127 - accuracy: 0.8244
# Epoch 61/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4123 - accuracy: 0.8237
# Epoch 62/100
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4114 - accuracy: 0.8246
# Epoch 63/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4119 - accuracy: 0.8244
# Epoch 64/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4120 - accuracy: 0.8264
# Epoch 65/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4110 - accuracy: 0.8248
# Epoch 66/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4114 - accuracy: 0.8248
# Epoch 67/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4116 - accuracy: 0.8256: 0s - loss:
# Epoch 68/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4106 - accuracy: 0.8239: 0s - loss: 0.4116 - accuracy: 0.82
# Epoch 69/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4108 - accuracy: 0.8237
# Epoch 70/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4109 - accuracy: 0.8267
# Epoch 71/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4101 - accuracy: 0.8252
# Epoch 72/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4109 - accuracy: 0.8251
# Epoch 73/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4105 - accuracy: 0.8247
# Epoch 74/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4102 - accuracy: 0.8253
# Epoch 75/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4088 - accuracy: 0.8262
# Epoch 76/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4092 - accuracy: 0.8259
# Epoch 77/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4094 - accuracy: 0.8245
# Epoch 78/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4087 - accuracy: 0.8260
# Epoch 79/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4083 - accuracy: 0.8256
# Epoch 80/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4092 - accuracy: 0.8263: 0s - loss:
# Epoch 81/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4093 - accuracy: 0.8261
# Epoch 82/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4095 - accuracy: 0.8272
# Epoch 83/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4079 - accuracy: 0.8260
# Epoch 84/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4075 - accuracy: 0.8267
# Epoch 85/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4075 - accuracy: 0.8244
# Epoch 86/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4072 - accuracy: 0.8268
# Epoch 87/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4068 - accuracy: 0.8269
# Epoch 88/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4070 - accuracy: 0.8264
# Epoch 89/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4076 - accuracy: 0.8253
# Epoch 90/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4070 - accuracy: 0.8272
# Epoch 91/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4065 - accuracy: 0.8265
# Epoch 92/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4076 - accuracy: 0.8251
# Epoch 93/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4067 - accuracy: 0.8273: 0s - loss: 0.4011 - ac
# Epoch 94/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4063 - accuracy: 0.8261
# Epoch 95/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4066 - accuracy: 0.8276
# Epoch 96/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4063 - accuracy: 0.8280: 0s
# Epoch 97/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4058 - accuracy: 0.8265
# Epoch 98/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4056 - accuracy: 0.8279
# Epoch 99/100
# 704/704 [==============================] - 1s 1ms/step - loss: 0.4046 - accuracy: 0.8264
# Epoch 100/100
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4053 - accuracy: 0.8265

# %% [markdown]
# 9. Plot the loss function and accuracy.

# %%
# Create a DataFrame with the history dictionary
df_plot = pd.DataFrame(model.history, index=range(1, len(model.history["loss"]) + 1))

# Plot the loss
df_plot.plot(y="loss")

# %%
# Plot the accuracy
df_plot.plot(y="accuracy")

# %% [markdown]
# 10. Evaluate the model using testing data and the `evaluate` method.

# %%
# Evaluate the model fit with linear dummy data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 235/235 - 0s - loss: 0.4465 - accuracy: 0.8151
# Loss: 0.4465479254722595, Accuracy: 0.8150666952133179

# %% [markdown]
# ## Challenge
#
# For this challenge section, you have to figure out how the model you created could be modified to improve the accuracy.
#
# 1. Review the Keras documentation about activation functions, and decide if there is anyone that could be used instead of `sigmoid`.
#
# 2. Add a second hidden layer with `69` units and use a different activation function than `sigmoid`.
#
# 3. Change any other parameter that you believe could improve the model's accuracy.
#
# 4. Evaluate the model's accuracy and loss and write down your conclusions.

# %%
# Define the model
number_inputs = 23
number_hidden_nodes = 120

nn_2 = Sequential()
nn_2.add(Dense(units=number_hidden_nodes, input_dim=number_inputs, activation="tanh"))
nn_2.add(Dense(units=1, activation="tanh"))

# %%
# Compile model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model
model = nn.fit(X_train_scaled, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 704/704 [==============================] - 2s 2ms/step - loss: 0.3976 - accuracy: 0.8283
# Epoch 2/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3967 - accuracy: 0.8323
# Epoch 3/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3964 - accuracy: 0.8296: 0s - loss: 0.3
# Epoch 4/50
# 704/704 [==============================] - 2s 2ms/step - loss: 0.3968 - accuracy: 0.8297
# Epoch 5/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3963 - accuracy: 0.8296
# Epoch 6/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3969 - accuracy: 0.8309
# Epoch 7/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3958 - accuracy: 0.8297
# Epoch 8/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3961 - accuracy: 0.8304
# Epoch 9/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3957 - accuracy: 0.8303
# Epoch 10/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3964 - accuracy: 0.8306
# Epoch 11/50
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3960 - accuracy: 0.8313
# Epoch 12/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3956 - accuracy: 0.8312
# Epoch 13/50
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3954 - accuracy: 0.8304
# Epoch 14/50
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3964 - accuracy: 0.8308
# Epoch 15/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3969 - accuracy: 0.8302
# Epoch 16/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3955 - accuracy: 0.8300
# Epoch 17/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3959 - accuracy: 0.8305
# Epoch 18/50
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3956 - accuracy: 0.8311
# Epoch 19/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3954 - accuracy: 0.8306
# Epoch 20/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3954 - accuracy: 0.8311
# Epoch 21/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3955 - accuracy: 0.8313
# Epoch 22/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3946 - accuracy: 0.8312
# Epoch 23/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3948 - accuracy: 0.8299
# Epoch 24/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3952 - accuracy: 0.8317
# Epoch 25/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3947 - accuracy: 0.8316
# Epoch 26/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3951 - accuracy: 0.8315
# Epoch 27/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3954 - accuracy: 0.8315
# Epoch 28/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3947 - accuracy: 0.8301
# Epoch 29/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3949 - accuracy: 0.8323
# Epoch 30/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3941 - accuracy: 0.8312
# Epoch 31/50
# 704/704 [==============================] - 2s 2ms/step - loss: 0.3944 - accuracy: 0.8321
# Epoch 32/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3951 - accuracy: 0.8322
# Epoch 33/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3937 - accuracy: 0.8327
# Epoch 34/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3944 - accuracy: 0.8307
# Epoch 35/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3947 - accuracy: 0.8321
# Epoch 36/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3949 - accuracy: 0.8315
# Epoch 37/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3940 - accuracy: 0.8336: 0s - loss: 0.3954 - accuracy:
# Epoch 38/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3940 - accuracy: 0.8322
# Epoch 39/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3935 - accuracy: 0.8317
# Epoch 40/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3949 - accuracy: 0.8328
# Epoch 41/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3937 - accuracy: 0.8323
# Epoch 42/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3938 - accuracy: 0.8319
# Epoch 43/50
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3943 - accuracy: 0.8321
# Epoch 44/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3932 - accuracy: 0.8318
# Epoch 45/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3957 - accuracy: 0.8317
# Epoch 46/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3937 - accuracy: 0.8318
# Epoch 47/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3938 - accuracy: 0.8301
# Epoch 48/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3943 - accuracy: 0.8319
# Epoch 49/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3937 - accuracy: 0.8323: 0s - loss: 0.3932 - accuracy:  - ETA: 0s - loss: 0.3917 - ac
# Epoch 50/50
# 704/704 [==============================] - 1s 1ms/step - loss: 0.3935 - accuracy: 0.8323

# %%
# Evaluate the model fit with linear dummy data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 235/235 - 0s - loss: 0.4597 - accuracy: 0.8104
# Loss: 0.45971396565437317, Accuracy: 0.8104000091552734

# %% [markdown]
# ### Conclusions
#
# It seems the results/accuracy does not get much better with the addition of the adam optimizer
