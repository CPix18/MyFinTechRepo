# %% [markdown]
# # Going Live with CCXT

# %% [markdown]
# ### Import Libraries and Dependencies

# %%
# Import libraries and dependencies
import ccxt
import os
import pandas as pd

# %% [markdown]
# ### Import Environment Variables

# %%
# Import environment variables
kraken_public_key = os.getenv('KRAKEN_PUBLIC_KEY')
kraken_secret_key = os.getenv('KRAKEN_SECRET_KEY')

# %% [markdown]
# ### Set Public and Private Keys for Kraken Exchange via the CCXT library

# %%
# Set the public and private keys for the API
exchange = ccxt.kraken({
    'apiKey': kraken_public_key,
    'secret': kraken_secret_key,
})

# %% [markdown]
# ### Connect to Kraken and Load Available Cyptocurrency Data

# %%
# Connect to Kraken and load the available cryptocurrencies
crypto_details = exchange.load_markets()

# Import data as a Pandas DataFrame
crypto_df = pd.DataFrame(crypto_details)
crypto_df
# Out:
#                                                       ADA/ETH  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 7}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                     ADAETH
# symbol                                                ADA/ETH
# base                                                      ADA
# quote                                                     ETH
# baseId                                                    ADA
# quoteId                                                  XETH
# darkpool                                                False
# info        {'altname': 'ADAETH', 'wsname': 'ADA/ETH', 'ac...
# altname                                                ADAETH
# active                                                   True
#
#                                                       ADA/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                     ADAEUR
# symbol                                                ADA/EUR
# base                                                      ADA
# quote                                                     EUR
# baseId                                                    ADA
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'ADAEUR', 'wsname': 'ADA/EUR', 'ac...
# altname                                                ADAEUR
# active                                                   True
#
#                                                       ADA/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                     ADAUSD
# symbol                                                ADA/USD
# base                                                      ADA
# quote                                                     USD
# baseId                                                    ADA
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'ADAUSD', 'wsname': 'ADA/USD', 'ac...
# altname                                                ADAUSD
# active                                                   True
#
#                                                       ADA/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 8}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                     ADAXBT
# symbol                                                ADA/BTC
# base                                                      ADA
# quote                                                     BTC
# baseId                                                    ADA
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'ADAXBT', 'wsname': 'ADA/XBT', 'ac...
# altname                                                ADAXBT
# active                                                   True
#
#                                                      ALGO/ETH  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 7}
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# id                                                    ALGOETH
# symbol                                               ALGO/ETH
# base                                                     ALGO
# quote                                                     ETH
# baseId                                                   ALGO
# quoteId                                                  XETH
# darkpool                                                False
# info        {'altname': 'ALGOETH', 'wsname': 'ALGO/ETH', '...
# altname                                               ALGOETH
# active                                                   True
#
#                                                      ALGO/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# id                                                    ALGOEUR
# symbol                                               ALGO/EUR
# base                                                     ALGO
# quote                                                     EUR
# baseId                                                   ALGO
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'ALGOEUR', 'wsname': 'ALGO/EUR', '...
# altname                                               ALGOEUR
# active                                                   True
#
#                                                      ALGO/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# id                                                    ALGOUSD
# symbol                                               ALGO/USD
# base                                                     ALGO
# quote                                                     USD
# baseId                                                   ALGO
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'ALGOUSD', 'wsname': 'ALGO/USD', '...
# altname                                               ALGOUSD
# active                                                   True
#
#                                                      ALGO/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 8}
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# id                                                    ALGOXBT
# symbol                                               ALGO/BTC
# base                                                     ALGO
# quote                                                     BTC
# baseId                                                   ALGO
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'ALGOXBT', 'wsname': 'ALGO/XBT', '...
# altname                                               ALGOXBT
# active                                                   True
#
#                                                      ATOM/ETH  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 6}
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# id                                                    ATOMETH
# symbol                                               ATOM/ETH
# base                                                     ATOM
# quote                                                     ETH
# baseId                                                   ATOM
# quoteId                                                  XETH
# darkpool                                                False
# info        {'altname': 'ATOMETH', 'wsname': 'ATOM/ETH', '...
# altname                                               ATOMETH
# active                                                   True
#
#                                                      ATOM/EUR  ...  \
# percentage                                               True  ...
# tierBased                                                True  ...
# taker                                                  0.0026  ...
# maker                                                  0.0016  ...
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...  ...
# precision                           {'amount': 8, 'price': 4}  ...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...  ...
# id                                                    ATOMEUR  ...
# symbol                                               ATOM/EUR  ...
# base                                                     ATOM  ...
# quote                                                     EUR  ...
# baseId                                                   ATOM  ...
# quoteId                                                  ZEUR  ...
# darkpool                                                False  ...
# info        {'altname': 'ATOMEUR', 'wsname': 'ATOM/EUR', '...  ...
# altname                                               ATOMEUR  ...
# active                                                   True  ...
#
#                                                       XRP/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# id                                                   XXRPZEUR
# symbol                                                XRP/EUR
# base                                                      XRP
# quote                                                     EUR
# baseId                                                   XXRP
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'XRPEUR', 'wsname': 'XRP/EUR', 'ac...
# altname                                                XRPEUR
# active                                                   True
#
#                                                       XRP/JPY  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# id                                                   XXRPZJPY
# symbol                                                XRP/JPY
# base                                                      XRP
# quote                                                     JPY
# baseId                                                   XXRP
# quoteId                                                  ZJPY
# darkpool                                                False
# info        {'altname': 'XRPJPY', 'wsname': 'XRP/JPY', 'ac...
# altname                                                XRPJPY
# active                                                   True
#
#                                                       XRP/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# id                                                   XXRPZUSD
# symbol                                                XRP/USD
# base                                                      XRP
# quote                                                     USD
# baseId                                                   XXRP
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'XRPUSD', 'wsname': 'XRP/USD', 'ac...
# altname                                                XRPUSD
# active                                                   True
#
#                                                       ZEC/BTC  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# id                                                   XZECXXBT
# symbol                                                ZEC/BTC
# base                                                      ZEC
# quote                                                     BTC
# baseId                                                   XZEC
# quoteId                                                  XXBT
# darkpool                                                False
# info        {'altname': 'ZECXBT', 'wsname': 'ZEC/XBT', 'ac...
# altname                                                ZECXBT
# active                                                   True
#
#                                                       ZEC/EUR  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# id                                                   XZECZEUR
# symbol                                                ZEC/EUR
# base                                                      ZEC
# quote                                                     EUR
# baseId                                                   XZEC
# quoteId                                                  ZEUR
# darkpool                                                False
# info        {'altname': 'ZECEUR', 'wsname': 'ZEC/EUR', 'ac...
# altname                                                ZECEUR
# active                                                   True
#
#                                                       ZEC/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                  0.0026
# maker                                                  0.0016
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 2}
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# id                                                   XZECZUSD
# symbol                                                ZEC/USD
# base                                                      ZEC
# quote                                                     USD
# baseId                                                   XZEC
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'ZECUSD', 'wsname': 'ZEC/USD', 'ac...
# altname                                                ZECUSD
# active                                                   True
#
#                                                       EUR/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# id                                                   ZEURZUSD
# symbol                                                EUR/USD
# base                                                      EUR
# quote                                                     USD
# baseId                                                   ZEUR
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'EURUSD', 'wsname': 'EUR/USD', 'ac...
# altname                                                EURUSD
# active                                                   True
#
#                                                       GBP/USD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# id                                                   ZGBPZUSD
# symbol                                                GBP/USD
# base                                                      GBP
# quote                                                     USD
# baseId                                                   ZGBP
# quoteId                                                  ZUSD
# darkpool                                                False
# info        {'altname': 'GBPUSD', 'wsname': 'GBP/USD', 'ac...
# altname                                                GBPUSD
# active                                                   True
#
#                                                       USD/CAD  \
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 5}
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# id                                                   ZUSDZCAD
# symbol                                                USD/CAD
# base                                                      USD
# quote                                                     CAD
# baseId                                                   ZUSD
# quoteId                                                  ZCAD
# darkpool                                                False
# info        {'altname': 'USDCAD', 'wsname': 'USD/CAD', 'ac...
# altname                                                USDCAD
# active                                                   True
#
#                                                       USD/JPY
# percentage                                               True
# tierBased                                                True
# taker                                                   0.002
# maker                                                   0.002
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
# precision                           {'amount': 8, 'price': 3}
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# id                                                   ZUSDZJPY
# symbol                                                USD/JPY
# base                                                      USD
# quote                                                     JPY
# baseId                                                   ZUSD
# quoteId                                                  ZJPY
# darkpool                                                False
# info        {'altname': 'USDJPY', 'wsname': 'USD/JPY', 'ac...
# altname                                                USDJPY
# active                                                   True
#
# [17 rows x 179 columns]

# %% [markdown]
# ### List Available Cryptocurrencies for Trading

# %%
# Print column values of DataFrame
print(type(crypto_df.columns.values))
print(crypto_df.columns.values)
print(len(crypto_df.columns.values))
# Out:
# <class 'numpy.ndarray'>
# ['ADA/ETH' 'ADA/EUR' 'ADA/USD' 'ADA/BTC' 'ALGO/ETH' 'ALGO/EUR' 'ALGO/USD'
#  'ALGO/BTC' 'ATOM/ETH' 'ATOM/EUR' 'ATOM/USD' 'ATOM/BTC' 'AUD/JPY'
#  'AUD/USD' 'BAT/ETH' 'BAT/EUR' 'BAT/USD' 'BAT/BTC' 'BCH/AUD' 'BCH/ETH'
#  'BCH/EUR' 'BCH/GBP' 'BCH/USD' 'BCH/USDT' 'BCH/BTC' 'DAI/EUR' 'DAI/USD'
#  'DAI/USDT' 'DASH/EUR' 'DASH/USD' 'DASH/BTC' 'EOS/ETH' 'EOS/EUR' 'EOS/USD'
#  'EOS/BTC' 'ETH/AUD' 'ETH/CHF' 'ETH/DAI' 'ETH/USDC' 'ETH/USDT' 'EUR/AUD'
#  'EUR/CAD' 'EUR/CHF' 'EUR/GBP' 'EUR/JPY' 'GNO/ETH' 'GNO/EUR' 'GNO/USD'
#  'GNO/BTC' 'ICX/ETH' 'ICX/EUR' 'ICX/USD' 'ICX/BTC' 'LINK/ETH' 'LINK/EUR'
#  'LINK/USD' 'LINK/BTC' 'LSK/ETH' 'LSK/EUR' 'LSK/USD' 'LSK/BTC' 'LTC/AUD'
#  'LTC/ETH' 'LTC/GBP' 'LTC/USDT' 'NANO/ETH' 'NANO/EUR' 'NANO/USD'
#  'NANO/BTC' 'OMG/ETH' 'OMG/EUR' 'OMG/USD' 'OMG/BTC' 'OXT/ETH' 'OXT/EUR'
#  'OXT/USD' 'OXT/BTC' 'PAXG/ETH' 'PAXG/EUR' 'PAXG/USD' 'PAXG/BTC'
#  'QTUM/ETH' 'QTUM/EUR' 'QTUM/USD' 'QTUM/BTC' 'SC/ETH' 'SC/EUR' 'SC/USD'
#  'SC/BTC' 'TRX/ETH' 'TRX/EUR' 'TRX/USD' 'TRX/BTC' 'USDC/EUR' 'USD/CHF'
#  'USDC/USD' 'USDC/USDT' 'USDT/AUD' 'USDT/CAD' 'USDT/CHF' 'USDT/EUR'
#  'USDT/GBP' 'USDT/JPY' 'USDT/USD' 'WAVES/ETH' 'WAVES/EUR' 'WAVES/USD'
#  'WAVES/BTC' 'BTC/AUD' 'BTC/CHF' 'BTC/DAI' 'BTC/USDC' 'BTC/USDT'
#  'DOGE/EUR' 'DOGE/USD' 'ETC/ETH' 'ETC/BTC' 'ETC/EUR' 'ETC/USD' 'ETH/BTC'
#  'ETHXBT.d' 'ETH/CAD' 'ETHCAD.d' 'ETH/EUR' 'ETHEUR.d' 'ETH/GBP' 'ETHGBP.d'
#  'ETH/JPY' 'ETHJPY.d' 'ETH/USD' 'ETHUSD.d' 'LTC/BTC' 'LTC/EUR' 'LTC/USD'
#  'MLN/ETH' 'MLN/BTC' 'MLN/EUR' 'MLN/USD' 'REP/ETH' 'REP/BTC' 'REP/EUR'
#  'REP/USD' 'XRP/AUD' 'XRP/ETH' 'XRP/GBP' 'XRP/USDT' 'XTZ/ETH' 'XTZ/EUR'
#  'XTZ/USD' 'XTZ/BTC' 'BTC/CAD' 'XBTCAD.d' 'BTC/EUR' 'XBTEUR.d' 'BTC/GBP'
#  'XBTGBP.d' 'BTC/JPY' 'XBTJPY.d' 'BTC/USD' 'XBTUSD.d' 'DOGE/BTC' 'XLM/BTC'
#  'XLM/EUR' 'XLM/USD' 'XMR/BTC' 'XMR/EUR' 'XMR/USD' 'XRP/BTC' 'XRP/CAD'
#  'XRP/EUR' 'XRP/JPY' 'XRP/USD' 'ZEC/BTC' 'ZEC/EUR' 'ZEC/USD' 'EUR/USD'
#  'GBP/USD' 'USD/CAD' 'USD/JPY']
# 179

# %%
# Show list of available functions for the current exchange (in this case Kraken)
exchange.has
# Out:
# {'loadMarkets': True,
#  'cancelAllOrders': False,
#  'cancelOrder': True,
#  'cancelOrders': False,
#  'CORS': False,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': False,
#  'editOrder': 'emulated',
#  'fetchBalance': True,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDepositAddress': True,
#  'fetchDeposits': True,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrders': False,
#  'fetchOrderTrades': 'emulated',
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchFundingFee': False,
#  'fetchFundingFees': False,
#  'fetchTradingLimits': False,
#  'fetchTransactions': False,
#  'fetchWithdrawals': True,
#  'privateAPI': True,
#  'publicAPI': True,
#  'withdraw': True,
#  'fetchLedgerEntry': True}

# %% [markdown]
# ### Fetch Historical Data for BTC/USD

# %%
# Fetch daily candlestick bar data from `BTC/USD`
historical_prices = exchange.fetch_ohlcv("BTC/USD", "1d")

# Import the data as a Pandas DataFrame and set the columns
historical_prices_df = pd.DataFrame(
    historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
historical_prices_df
# Out:
#          timestamp    open    high     low   close       volume
# 0    1530403200000  6387.0  6433.3  6254.3  6345.8  1940.389407
# 1    1530489600000  6345.8  6678.7  6275.0  6617.7  3636.666731
# 2    1530576000000  6618.7  6670.0  6467.6  6495.5  2754.871147
# 3    1530662400000  6497.0  6790.0  6399.8  6584.2  3811.898492
# 4    1530748800000  6587.0  6715.2  6450.0  6526.2  3316.814603
# ..             ...     ...     ...     ...     ...          ...
# 715  1592179200000  9330.4  9499.9  8905.0  9425.3  9822.248348
# 716  1592265600000  9425.3  9589.0  9385.0  9528.5  5098.313037
# 717  1592352000000  9527.5  9556.8  9233.4  9453.1  4753.617778
# 718  1592438400000  9453.1  9480.0  9268.3  9381.5  3470.308495
# 719  1592524800000  9381.5  9381.5  9256.5  9271.0   569.225823
#
# [720 rows x 6 columns]

# %% [markdown]
# ### Convert Epoch Timestamp to Readable Date Format

# %%
# Convert epoch timestamp to date using the `to_datetime` function and `unit` parameter
historical_prices_df["date"] = pd.to_datetime(
    historical_prices_df["timestamp"], unit="ms"
)
historical_prices_df.head()
# Out:
#        timestamp    open    high     low   close       volume       date
# 0  1530403200000  6387.0  6433.3  6254.3  6345.8  1940.389407 2018-07-01
# 1  1530489600000  6345.8  6678.7  6275.0  6617.7  3636.666731 2018-07-02
# 2  1530576000000  6618.7  6670.0  6467.6  6495.5  2754.871147 2018-07-03
# 3  1530662400000  6497.0  6790.0  6399.8  6584.2  3811.898492 2018-07-04
# 4  1530748800000  6587.0  6715.2  6450.0  6526.2  3316.814603 2018-07-05

# %% [markdown]
# ### Fetch Latest Data for BTC/USD

# %%
# Fetch current price details for `BTC/USD`
current_price = exchange.fetch_ticker('BTC/USD')

# Delete `info` key-value pair
del current_price['info']

current_price
# Out:
# {'symbol': 'BTC/USD',
#  'timestamp': 1592538039661,
#  'datetime': '2020-06-19T03:40:39.661Z',
#  'high': 9480.0,
#  'low': 9256.5,
#  'bid': 9271.0,
#  'bidVolume': None,
#  'ask': 9271.1,
#  'askVolume': None,
#  'vwap': 9373.40283,
#  'open': 9381.5,
#  'close': 9271.0,
#  'last': 9271.0,
#  'previousClose': None,
#  'change': None,
#  'percentage': None,
#  'average': None,
#  'baseVolume': 3986.01276192,
#  'quoteVolume': 37362503.302997045}

# %%
# Import data as a Pandas DataFrame
current_price_df = pd.DataFrame(current_price, index=[0])
current_price_df
# Out:
#     symbol      timestamp                  datetime    high     low     bid  \
# 0  BTC/USD  1592538039661  2020-06-19T03:40:39.661Z  9480.0  9256.5  9271.0
#
#   bidVolume     ask askVolume        vwap    open   close    last  \
# 0      None  9271.1      None  9373.40283  9381.5  9271.0  9271.0
#
#   previousClose change percentage average   baseVolume   quoteVolume
# 0          None   None       None    None  3986.012762  3.736250e+07

# %%
# Fetch balance
exchange.fetch_balance()
# Out:
# {'info': {}, 'free': {}, 'used': {}, 'total': {}}

# %%
# Fetch status
exchange.fetch_status()
# Out:
# {'status': 'ok', 'updated': 1592538043000, 'eta': None, 'url': None}

# %%
# Fetch open orders
exchange.fetch_open_orders()
# Out:
# []
