# %% [markdown]
# # Spring Cleaning!

# %% [markdown]
# Harold's stock data is a mess! Help him clean up his data before the auditors arrive!

# %%
# Import Libraries
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Load CSV data into Pandas using `read_csv`

# %%
csv_path = Path("../../Resources/stock_data.csv")
csv_data = pd.read_csv(csv_path)

# %% [markdown]
# ### Identify the number of rows and columns (shape) in the DataFrame.

# %%
csv_data.shape
# Out:
# (478, 14)

# %% [markdown]
# ### Generate a sample of the data to visually ensure data has been loaded in correctly.

# %%
csv_data.sample(10)
# Out:
#     symbol                                 name                  sector  \
# 247    ICE            Intercontinental Exchange              Financials
# 40    AMGN                            Amgen Inc             Health Care
# 154    DPS              Dr Pepper Snapple Group        Consumer Staples
# 210    GIS                        General Mills        Consumer Staples
# 276     LH  Laboratory Corp. of America Holding             Health Care
# 200    FTV                         Fortive Corp             Industrials
# 219    HBI                      Hanesbrands Inc  Consumer Discretionary
# 269    KMI                        Kinder Morgan                  Energy
# 305    MTD                       Mettler Toledo             Health Care
# 10     AET                            Aetna Inc             Health Care
#
#       price  price_per_earnings  dividend_yield earnings_per_share  \
# 247      67               22.95        5.429864               2.37
# 40   173.12               13.76        2.975151               2.57
# 154  116.93               26.57        1.966102               4.54
# 210   53.99               17.53        3.586459               2.77
# 276  165.46               17.79        0.000000               7.02
# 200   69.14               25.05        0.390571               2.46
# 219   19.57               10.04        2.732240               1.41
# 269    16.8               25.07        2.891845               0.01
# 305     601               35.56        0.000000              14.24
# 10      178               18.11        1.101989               5.75
#
#      52_week_low  52_week_high    market_cap        ebitda  price_per_sales  \
# 247      76.1378       56.8000  4.137305e+10  3.103000e+09         9.619987
# 40      201.2300      152.1600  1.281333e+11  1.194500e+10         5.581920
# 154     126.6500       83.2300  2.120978e+10  1.507000e+09         4.214919
# 210      63.7300       49.6500  3.109824e+10  3.107600e+09         2.038918
# 276     181.7150      130.2920  1.727139e+10  1.861200e+09         2.245962
# 200      76.6800       54.8844  2.491650e+10  1.508300e+09         5.168267
# 219      25.7300       18.9000  8.006269e+09  9.261530e+08         1.633977
# 269      22.7500       16.5600  3.861271e+10  5.981000e+09         2.823936
# 305     697.2600      459.3400  1.642077e+10  6.667060e+08         8.372307
# 10      194.4000      119.5100  5.919702e+10  4.139000e+09         0.992355
#
#      price_per_book                                        sec_filings
# 247            2.62  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 40             3.91  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 154            9.99  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 210            7.26  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 276            2.71  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 200            7.17  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 219            6.17  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 269            1.07  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 305           31.69  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 10             3.79  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %% [markdown]
# ### Identify the number of records in the DataFrame, and compare it with the number of rows in the original file.

# %%
csv_data.head()
# Out:
#   symbol                 name                  sector    price  \
# 0    MMM           3M Company             Industrials  $222.89
# 1    AOS      A.O. Smith Corp             Industrials      NaN
# 2    ABT  Abbott Laboratories             Health Care    56.27
# 3   ABBV          AbbVie Inc.             Health Care   108.48
# 4   ATVI  Activision Blizzard  Information Technology    65.83
#
#    price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 0               24.31        2.332862              $7.92      259.770
# 1                 NaN             NaN                NaN          NaN
# 2               22.51        1.908982               0.26       64.600
# 3               19.41        2.499560               3.29      125.860
# 4                 NaN        0.431903               1.28       74.945
#
#    52_week_high    market_cap        ebitda  price_per_sales  price_per_book  \
# 0        175.49  1.387211e+11  9.048000e+09         4.390271           11.34
# 1           NaN           NaN           NaN              NaN             NaN
# 2         42.28  1.021210e+11  5.744000e+09         3.740480            3.19
# 3         60.05  1.813863e+11  1.031000e+10         6.291571           26.14
# 4         38.93  5.251867e+10  2.704000e+09        10.595120            5.16
#
#                                          sec_filings
# 0  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1                                                NaN
# 2  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 4  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %% [markdown]
# ### Identify nulls records

# %%
csv_data.isnull().mean() * 100
# Out:
# symbol                0.0
# name                  0.0
# sector                0.0
# price                 0.0
# price_per_earnings    0.0
# dividend_yield        0.0
# earnings_per_share    0.0
# 52_week_low           0.0
# 52_week_high          0.0
# market_cap            0.0
# ebitda                0.0
# price_per_sales       0.0
# price_per_book        0.0
# sec_filings           0.0
# dtype: float64

# %% [markdown]
# ### Drop Null Records

# %%
csv_data.dropna(inplace=True)
csv_data
# Out:
#     symbol                    name                  sector    price  \
# 0      MMM              3M Company             Industrials  $222.89
# 2      ABT     Abbott Laboratories             Health Care    56.27
# 3     ABBV             AbbVie Inc.             Health Care   108.48
# 5      AYI       Acuity Brands Inc             Industrials   108.48
# 6     ADBE       Adobe Systems Inc  Information Technology   185.16
# ..     ...                     ...                     ...      ...
# 499    XYL              Xylem Inc.             Industrials    70.24
# 500    YUM         Yum! Brands Inc  Consumer Discretionary     76.3
# 501    ZBH  Zimmer Biomet Holdings             Health Care   115.53
# 502   ZION           Zions Bancorp              Financials    50.71
# 503    ZTS                  Zoetis             Health Care    71.51
#
#      price_per_earnings  dividend_yield earnings_per_share  52_week_low  \
# 0                 24.31        2.332862              $7.92       259.77
# 2                 22.51        1.908982               0.26        64.60
# 3                 19.41        2.499560               3.29       125.86
# 5                 18.22        0.351185               7.43       225.36
# 6                 52.31        0.000000               3.39       204.45
# ..                  ...             ...                ...          ...
# 499               30.94        1.170079               1.83        76.81
# 500               27.25        1.797080               4.07        86.93
# 501               14.32        0.794834               9.01       133.49
# 502               17.73        1.480933                2.6        55.61
# 503               32.80        0.682372               1.65        80.13
#
#      52_week_high    market_cap        ebitda  price_per_sales  \
# 0         175.490  1.387211e+11  9.048000e+09         4.390271
# 2          42.280  1.021210e+11  5.744000e+09         3.740480
# 3          60.050  1.813863e+11  1.031000e+10         6.291571
# 5         142.000  6.242378e+09  5.878000e+08         1.795347
# 6         114.451  9.455021e+10  2.538040e+09        13.092818
# ..            ...           ...           ...              ...
# 499        46.860  1.291502e+10  7.220000e+08         2.726209
# 500        62.850  2.700330e+10  2.289000e+09         6.313636
# 501       108.170  2.445470e+10  2.007400e+09         3.164895
# 502        38.430  1.067068e+10  0.000000e+00         3.794579
# 503        52.000  3.599111e+10  1.734000e+09         9.280896
#
#      price_per_book                                        sec_filings
# 0             11.34  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 2              3.19  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 3             26.14  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 5              3.55  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 6             11.06  http://www.sec.gov/cgi-bin/browse-edgar?action...
# ..              ...                                                ...
# 499            5.31  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 500          212.08  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 501            2.39  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 502            1.42  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 503           18.09  http://www.sec.gov/cgi-bin/browse-edgar?action...
#
# [478 rows x 14 columns]

# %% [markdown]
# ### Validate nulls have been dropped

# %%
csv_data.isnull().sum()
# Out:
# symbol                0
# name                  0
# sector                0
# price                 0
# price_per_earnings    0
# dividend_yield        0
# earnings_per_share    0
# 52_week_low           0
# 52_week_high          0
# market_cap            0
# ebitda                0
# price_per_sales       0
# price_per_book        0
# sec_filings           0
# dtype: int64

# %% [markdown]
# ### Default null `ebitda` values to 0. Then, validate no records are null for ebitda.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5403119919ca> in <module>
# ----> 1 csv_data.isnull(ebitda)
#
# NameError: name 'ebitda' is not defined

# %% [markdown]
# ### Drop Duplicates

# %% [markdown]
# ### Sample `price` field

# %% [markdown]
# ### Clean `price` Series by replacing `$`

# %% [markdown]
# ### Confirm data type of `price`

# %% [markdown]
# ### Cast `price` Series as float and then validate using `dtype`
